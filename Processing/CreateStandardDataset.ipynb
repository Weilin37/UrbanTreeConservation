# %%
import pandas as pd
from os import listdir
from os.path import isfile, join

# %%
# Find files
path = "Final Spreadsheets"
files = [f for f in listdir(path) if isfile(join(path, f))]

# %%
# Loop through files
df = pd.read_csv(path+"/Albuquerque_Final_2021-03-22.csv")
df = df.iloc[0:0]

for file in files:
    # Read data
    tmpdf = pd.read_csv(path+"/"+file)
    df = df.append(tmpdf)

# %%
df = df.drop_duplicates()
df.to_csv('standard_dataset.csv', index=False)

# %%
df
# Out:
#       most_recent_observation most_recent_observation_type  common_name  \
# 0                   6/17/2020               inventory_date       Locust
# 1                    6/9/2020               inventory_date          Oak
# 2                    6/3/2020               inventory_date          Ash
# 3                    6/3/2020               inventory_date  Scotch pine
# 4                   5/29/2020               inventory_date  Honeylocust
# ...                       ...                          ...          ...
# 17449                     NaN                          NaN          NaN
# 17450                     NaN                          NaN          NaN
# 17451                     NaN                          NaN          NaN
# 17452                     NaN                          NaN          NaN
# 17453                     NaN                          NaN          NaN
#
#              scientific_name         city          state  \
# 0                        NaN  Albuquerque     New Mexico
# 1                    Quercus  Albuquerque     New Mexico
# 2                   Fraxinus  Albuquerque     New Mexico
# 3           Pinus sylvestris  Albuquerque     New Mexico
# 4      Gleditsia triacanthos  Albuquerque     New Mexico
# ...                      ...          ...            ...
# 17449        Zelkova serrata    Worcester  Massachusetts
# 17450        Zelkova serrata    Worcester  Massachusetts
# 17451        Zelkova serrata    Worcester  Massachusetts
# 17452        Zelkova serrata    Worcester  Massachusetts
# 17453        Zelkova serrata    Worcester  Massachusetts
#
#        longitude_coordinate  latitude_coordinate  \
# 0               -106.568366            35.060456
# 1               -106.655037            35.139272
# 2               -106.581127            35.052176
# 3               -106.575056            35.052450
# 4               -106.716539            35.149632
# ...                     ...                  ...
# 17449                   NaN                  NaN
# 17450                   NaN                  NaN
# 17451                   NaN                  NaN
# 17452                   NaN                  NaN
# 17453                   NaN                  NaN
#
#                               address   condition  ...  retired_date  \
# 0                                 NaN  dead/dying  ...           NaN
# 1       1641 Tierra Del Rio Northwest         NaN  ...           NaN
# 2           Us Veterans Hospital Loop  dead/dying  ...           NaN
# 3      1606 San Pedro Drive Southeast  dead/dying  ...           NaN
# 4        5700 Bogart Street Northwest        good  ...           NaN
# ...                               ...         ...  ...           ...
# 17449                             NaN         NaN  ...           NaN
# 17450                             NaN         NaN  ...           NaN
# 17451                             NaN         NaN  ...           NaN
# 17452                             NaN         NaN  ...           NaN
# 17453                             NaN         NaN  ...           NaN
#
#       location_type zipcode neighborhood location_name ward  district  \
# 0               NaN     NaN          NaN           NaN  NaN       NaN
# 1               NaN     NaN          NaN           NaN  NaN       NaN
# 2               NaN     NaN          NaN           NaN  NaN       NaN
# 3               NaN     NaN          NaN           NaN  NaN       NaN
# 4               NaN     NaN          NaN           NaN  NaN       NaN
# ...             ...     ...          ...           ...  ...       ...
# 17449           NaN     NaN          NaN           NaN  NaN       NaN
# 17450           NaN     NaN          NaN           NaN  NaN       NaN
# 17451           NaN     NaN          NaN           NaN  NaN       NaN
# 17452           NaN     NaN          NaN           NaN  NaN       NaN
# 17453           NaN     NaN          NaN           NaN  NaN       NaN
#
#       overhead_utility diameter_breast_height_CM percent_population
# 0                  NaN                       NaN                NaN
# 1                  NaN                       NaN                NaN
# 2                  NaN                       NaN                NaN
# 3                  NaN                       NaN                NaN
# 4                  NaN                       NaN                NaN
# ...                ...                       ...                ...
# 17449              NaN                       NaN                NaN
# 17450              NaN                       NaN                NaN
# 17451              NaN                       NaN                NaN
# 17452              NaN                       NaN                NaN
# 17453              NaN                       NaN                NaN
#
# [5132890 rows x 28 columns]

# %%
df_final[df_final['diameter_breast_height_CM'] ]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: True
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-91f7d59161ce> in <module>
# ----> 1 df_final[len(df_final['diameter_breast_height_CM'])>0]
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: True

# %%
columns
# Out:
# ['city',
#  'state',
#  'native',
#  'scientific_name',
#  'condition',
#  'diameter_breast_height_CM',
#  'diameter_breast_height_binned_CM',
#  'latitude_coordinate',
#  'longitude_coordinate']
